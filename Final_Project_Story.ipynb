# %% [markdown]
# # Module 8 - Final Project
#
# You have made it to the end of the course, and you have worked hard to develop your DSA perspectives and skills.  So far we have been internally focused on the operations of performing data science and analytics.  Now we will extend our work to the development of a data story that is externally focused.
#
# In the Module8 labs, you saw simplified examples of constructing data stories. In module4 (Database) there also was an abbreviated example data story.  Throughout the course, there are components and parts useful to consider as a basis for developing a short, unique, focused data story.
#
#
# For this final project, you will
#
# - Step 0: Choose your Language for this Adventure
#
# - Step 1: Find a Story
#
# - Step 2: Remember your Audience
#
# - Step 3: Find and Stage Your Data
#
# - Step 4: Vet Data Sources
#
# - Step 5: Filter Results and Build/Validate Models
#
# - Step 6: Visualize Results
#
# - Step 7: Communicate the Story to your intended audience using visualizations and narratives
#
# - Final Step: Connect your workflow/process to the DSA-Project Life Cycle
#
# ---
# Here are some recommendations for managing the scope and quality of this project:
#
# - Narrow down the issue, problem, question, or hypothesis for you data story to a single, relatively simple perspective.
#
# - Identify already available data that affords addressing your problem.  If using completely new data, know it well.
#
# - Address the data relative to the statistical/machine learning model(s) chosen to minimize any issues.
#
# - Internally document your code using comments that explain the purpose of the operation(s).
#
#
# Make your project unique by
#
# - Comparing two or more different statistical/machine learning models using the same data.
# - Refrain from identically replicating any existing projects obtained from external sources.
# - Running a single model multiple times and changing a different single parameter each time for comparison.
# - Changing the sampling proportions for building the hold-out data and comparing the same model performance repeatedly.
# - Select something you find interesting or unique in the data and write a story around it.

# %% [markdown]
# ## Step 0: Choose your Language for this Adventure:
#
# You can do this project in either *R* or *Python*.
#
# To change the kernel of this notebook, do the following with the `Kernel` menu.
#
#  * `Kernel > Change Kernel > Python 3`
#  * `Kernel > Change Kernel > R`
#
# ![FP_Change_Kernel.png MISSING](../images/FP_Change_Kernel.png)

# %% [markdown]
# ---
# ## Step 1: Find a Story
#
# Think back to any of the data files we have used in this class.
# Alternatively, you can search online for potential data and story ideas.
#
# In the cell below, please detail the source of your data (with link).
# Additionally, preview the story you hope to uncover.

# %% [markdown]
# #### I am using 2 datasets to build my prediction model and their source links are-
#
# #### 1. Apple.Inc historical stock data - https://www.nasdaq.com/market-activity/stocks/aapl
# #### 2. Microsoft.Inc historical stock data - https://www.nasdaq.com/market-activity/stocks/msft
#
# #### My prediction model is aimed to predict the trading volume of the stocks in order to quantify the health of that particular stock.
# #### Each dataset consists of the historical stock values for the years 2020 and 2021, so they have 505 rows and 6 columns in each dataset.
# #### The column names are - Date, Opening Price, Highest Price, Lowest Price, Closing Price, and Trade volume.
# #### Date - The date column mentions the date to which the stock information belongs.
# #### Opening Price - The opening price mentions the stock price at the opening time of the stock market on that day.
# #### Highest Price - The highest price mentions the highest point the stock price reached on that particular day.
# #### Lowest Price - The lowest price mentions the lowest point the stock price reached on that particular day.
# #### Closing Price - The closing price mentions the stock price at the closing time of the stock market on that day.
# #### Trade Volume - The trade volume mentions the number of shares that were traded on that particular day.

# %% [markdown]
# ## Step 2: Remember your Audience
#
# In the cell below, describe your audience!
#  * Who will the audience be?
#  * What value will they derive from your story?

# %% [markdown]
# #### 1. My audience would be the day traders or long time investors would wish to seek infomration about stock performance inorder to buy them.
#
# #### 2. The audience would derive the information about the health of a stock based on the volume of trades that were performed on a  single day.

# %% [markdown]
# ## Step 3: Find and Stage Your Data
#
# If you data is from another source, such as Kaggle, you must download it to your local computer, then upload the data to JuptyerHub.
#
# #### If you are uploading files:
#  * Use folder navigation of your first JupyterTab to get to course's `/modules/module8/exercises/` folder.
# ![FP_Folder_Navigation.png MISSING](../images/FP_Folder_Navigation.png)
#  * Click the Upload Button and Choose File(s)
# ![FP_Upload_Button.png MISSING](../images/FP_Upload_Button.png)
#  * Activate the upload
# ![FP_UploadFile_2.png MISSING](../images/FP_UploadFile_2.png)
#
#
# ### In the cell below, please list the name(s) of the file(s) that are now accessible on the JupyterHub environment.
#
# **Note**:
# If you uploaded a file to your `module8/exercises` folder, the file name is all you need to load it into the data frame in the usual manner.
# If you are using a file from another module of the course, you should be able to copy the full pathname and use it as is in this notebook.

# %% [markdown]
# ### The names of my 2 dataset files are -
# ### 1. Apple.csv
# ### 2. Microsoft.csv
# ### They are located in the myData folder.

# %% [markdown]
# ## Step 4: Vet Data Sources
#
# Use the cells below to load the data, inspect it, conduct data carpentry and shaping; perform exploratory data analysis.
#
# Add more cells (`Insert > Insert Cell Below`) if you want additional cells.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn import linear_model

# %% [markdown]
# ### Vetting the historical stock data of Apple.Inc

# %%
Apple = pd.read_csv('myData/Apple.csv')

# %%
Apple
# Out:
#            Date  Opening Price($)  Closing Price($)  Highest Price($)  \
# 0    01-02-2020             74.06             75.09             75.15
# 1    01-03-2020             74.29             74.36             75.15
# 2    01-06-2020             73.45             74.95             74.99
# 3    01-07-2020             74.96             74.60             75.23
# 4    01-08-2020             74.29             75.80             76.11
# ..          ...               ...               ...               ...
# 500  12-27-2021            177.09            180.33            180.42
# 501  12-28-2021            180.16            179.29            181.33
# 502  12-29-2021            179.33            179.38            180.63
# 503  12-30-2021            179.47            178.20            180.57
# 504  12-31-2021            178.09            177.57            179.23
#
#      Lowest Price($)  Trade Volume
# 0              73.80     135647440
# 1              74.13     146535520
# ...

# %%
Apple_candlestick = go.Figure(data=[go.Candlestick(x=Apple['Date'],
                                                   open=Apple['Opening Price($)'],
                                                   high=Apple['Highest Price($)'],
                                                   low=Apple['Lowest Price($)'],
                                                   close=Apple['Closing Price($)'])])

Apple_candlestick.show(figsize=(15,5))
# Out:
# <div>
#
#
#             <div id="a60c2cc5-0cd2-4631-8a8e-50439272ad81" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a60c2cc5-0cd2-4631-8a8e-50439272ad81")) {
#                     Plotly.newPlot(
#                         'a60c2cc5-0cd2-4631-8a8e-50439272ad81',
# ...

# %%
Apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 6 columns):
# Date                505 non-null object
# Opening Price($)    505 non-null float64
# Closing Price($)    505 non-null float64
# Highest Price($)    505 non-null float64
# Lowest Price($)     505 non-null float64
# Trade Volume        505 non-null int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 23.8+ KB

# %%
Apple=Apple.dropna()

# %%
boxplot = Apple.boxplot(column=['Opening Price($)','Closing Price($)','Highest Price($)','Lowest Price($)'],figsize=(15,5))

# %% [markdown]
# #### Note: Since there are no null values and not many outliers in the Apple.Inc data, I am creating a prediction model including all the columns.

# %% [markdown]
# ### Vetting the historical stock data of Microsoft.Inc

# %%
Microsoft = pd.read_csv('myData/Microsoft.csv')

# %%
Microsoft
# Out:
#            Date  Opening Price($)  Closing Price($)  Highest Price($)  \
# 0    01-02-2020            158.78            160.62            160.73
# 1    01-03-2020            158.32            158.62            159.95
# 2    01-06-2020            157.08            159.03            159.10
# 3    01-07-2020            159.32            157.58            159.67
# 4    01-08-2020            158.93            160.09            160.80
# ..          ...               ...               ...               ...
# 500  12-27-2021            335.46            342.45            342.48
# 501  12-28-2021            343.15            341.25            343.81
# 502  12-29-2021            341.30            341.95            344.30
# 503  12-30-2021            341.91            339.32            343.13
# 504  12-31-2021            338.51            336.32            339.36
#
#      Lowest Price($)  Trade Volume
# 0             158.33      22634550
# 1             158.06      21121680
# ...

# %%
Microsoft_candlestick = go.Figure(data=[go.Candlestick(x=Microsoft['Date'],
                                                   open=Microsoft['Opening Price($)'],
                                                   high=Microsoft['Highest Price($)'],
                                                   low=Microsoft['Lowest Price($)'],
                                                   close=Microsoft['Closing Price($)'])])

Microsoft_candlestick.show(figsize=(15,5))
# Out:
# <div>
#
#
#             <div id="10901581-fe23-41cf-96aa-9770c8283b51" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("10901581-fe23-41cf-96aa-9770c8283b51")) {
#                     Plotly.newPlot(
#                         '10901581-fe23-41cf-96aa-9770c8283b51',
# ...

# %%
Microsoft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 6 columns):
# Date                505 non-null object
# Opening Price($)    505 non-null float64
# Closing Price($)    505 non-null float64
# Highest Price($)    505 non-null float64
# Lowest Price($)     505 non-null float64
# Trade Volume        505 non-null int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 23.8+ KB

# %%
Microsoft=Microsoft.dropna()

# %%
boxplot = Microsoft.boxplot(column=['Opening Price($)','Closing Price($)','Highest Price($)','Lowest Price($)'],figsize=(15,5))

# %% [markdown]
# #### Note: Since there are no null values and not many outliers in the Microsoft.Inc data, I am creating a prediction model including all the columns.

# %% [markdown]
# ## Step 5: Filter Results and Build and Validate Models
#
#
# Perform any additional data carpentry and begin filtering results/data and then build, validate, and describe your model(s).
#
# Add more cells (`Insert > Insert Cell Below`) if you want additional cells.

# %% [markdown]
# ### Building a data model using the stock data of Apple.Inc

# %%
Apple=Apple.rename(columns={"Opening Price($)": "Apple Opening Price($)", "Closing Price($)": "Apple Closing Price($)",
                            "Highest Price($)": "Apple Highest Price($)", "Lowest Price($)": "Apple Lowest Price($)",
                            "Trade Volume": "Apple Trade Volume"})

# %%
Apple
# Out:
#            Date  Apple Opening Price($)  Apple Closing Price($)  \
# 0    01-02-2020                   74.06                   75.09
# 1    01-03-2020                   74.29                   74.36
# 2    01-06-2020                   73.45                   74.95
# 3    01-07-2020                   74.96                   74.60
# 4    01-08-2020                   74.29                   75.80
# ..          ...                     ...                     ...
# 500  12-27-2021                  177.09                  180.33
# 501  12-28-2021                  180.16                  179.29
# 502  12-29-2021                  179.33                  179.38
# 503  12-30-2021                  179.47                  178.20
# 504  12-31-2021                  178.09                  177.57
#
#      Apple Highest Price($)  Apple Lowest Price($)  Apple Trade Volume
# 0                     75.15                  73.80           135647440
# ...

# %%
train_apple = Apple.sample(frac=0.75, random_state=1)
test_apple = Apple.drop(train_apple.index)

# %%
train_apple
# Out:
#            Date  Apple Opening Price($)  Apple Closing Price($)  \
# 307  03-23-2021                  123.33                  122.54
# 343  05-13-2021                  124.58                  124.97
# 47   03-11-2020                   69.35                   68.86
# 67   04-08-2020                   65.69                   66.52
# 361  06-09-2021                  127.21                  127.13
# ..          ...                     ...                     ...
# 240  12-14-2020                  122.60                  121.78
# 57   03-25-2020                   62.69                   61.38
# 301  03-15-2021                  121.41                  123.99
# 450  10-14-2021                  142.11                  143.76
# 359  06-07-2021                  126.17                  125.90
#
#      Apple Highest Price($)  Apple Lowest Price($)  Apple Trade Volume
# 307                  124.24                 122.14            95467140
# ...

# %%
test_apple
# Out:
#            Date  Apple Opening Price($)  Apple Closing Price($)  \
# 1    01-03-2020                   74.29                   74.36
# 2    01-06-2020                   73.45                   74.95
# 3    01-07-2020                   74.96                   74.60
# 7    01-13-2020                   77.91                   79.24
# 15   01-24-2020                   80.06                   79.58
# ..          ...                     ...                     ...
# 471  11-12-2021                  148.43                  149.99
# 488  12-08-2021                  172.13                  175.08
# 491  12-13-2021                  181.12                  175.74
# 498  12-22-2021                  173.04                  175.64
# 499  12-23-2021                  175.85                  176.28
#
#      Apple Highest Price($)  Apple Lowest Price($)  Apple Trade Volume
# 1                     75.15                  74.13           146535520
# ...

# %%
train_apple_x = np.asarray(train_apple[['Apple Opening Price($)','Apple Closing Price($)','Apple Highest Price($)','Apple Lowest Price($)']])
train_apple_y = np.asarray(train_apple['Apple Trade Volume'])

test_apple_x = np.asarray(test_apple[['Apple Opening Price($)','Apple Closing Price($)','Apple Highest Price($)','Apple Lowest Price($)']])
test_apple_y = np.asarray(test_apple['Apple Trade Volume'])

# %%
regression_apple = linear_model.LinearRegression()
regression_apple.fit(train_apple_X,train_apple_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Regression Intercept:', regression_apple.intercept_)
print('Regression Coefficients:', regression_apple.coef_)
# Out:
# Regression Intercept: 223610404.19329923
# Regression Coefficients: [ -8065453.44697295  -5946468.35955614  33092491.55468118
#  -20544641.03417457]

# %%
print('R-Squared value of the Apple training set: {}'.format(regression_apple.score(train_apple_x, train_apple_y)))
print('R-Squared value of the Apple testing set: {}'.format(regression_apple.score(test_apple_x, test_apple_y)))
# Out:
# R-Squared value of the Apple training set: 0.670602515197351
# R-Squared value of the Apple testing set: 0.658464825607165

# %% [markdown]
# ### Building a data model using the stock data of Microsoft.Inc

# %%
Microsoft=Microsoft.rename(columns={"Opening Price($)": "Microsoft Opening Price($)", "Closing Price($)": "Microsoft Closing Price($)",
                                    "Highest Price($)": "Microsoft Highest Price($)", "Lowest Price($)": "Microsoft Lowest Price($)",
                                    "Trade Volume": "Microsoft Trade Volume"})

# %%
Microsoft
# Out:
#            Date  Microsoft Opening Price($)  Microsoft Closing Price($)  \
# 0    01-02-2020                      158.78                      160.62
# 1    01-03-2020                      158.32                      158.62
# 2    01-06-2020                      157.08                      159.03
# 3    01-07-2020                      159.32                      157.58
# 4    01-08-2020                      158.93                      160.09
# ..          ...                         ...                         ...
# 500  12-27-2021                      335.46                      342.45
# 501  12-28-2021                      343.15                      341.25
# 502  12-29-2021                      341.30                      341.95
# 503  12-30-2021                      341.91                      339.32
# 504  12-31-2021                      338.51                      336.32
#
#      Microsoft Highest Price($)  Microsoft Lowest Price($)  \
# ...

# %%
train_microsoft = Microsoft.sample(frac=0.75, random_state=1)
test_microsoft = Microsoft.drop(train_microsoft.index)

# %%
train_microsoft
# Out:
#            Date  Microsoft Opening Price($)  Microsoft Closing Price($)  \
# 307  03-23-2021                      237.49                      237.58
# 343  05-13-2021                      241.80                      243.03
# 47   03-11-2020                      157.13                      153.63
# 67   04-08-2020                      165.67                      165.13
# 361  06-09-2021                      253.81                      253.59
# ..          ...                         ...                         ...
# 240  12-14-2020                      213.10                      214.20
# 57   03-25-2020                      148.91                      146.92
# 301  03-15-2021                      234.96                      234.81
# 450  10-14-2021                      299.21                      302.75
# 359  06-07-2021                      249.98                      253.81
#
#      Microsoft Highest Price($)  Microsoft Lowest Price($)  \
# ...

# %%
test_microsoft
# Out:
#            Date  Microsoft Opening Price($)  Microsoft Closing Price($)  \
# 1    01-03-2020                      158.32                      158.62
# 2    01-06-2020                      157.08                      159.03
# 3    01-07-2020                      159.32                      157.58
# 7    01-13-2020                      161.76                      163.28
# 15   01-24-2020                      167.51                      165.04
# ..          ...                         ...                         ...
# 471  11-12-2021                      333.92                      336.72
# 488  12-08-2021                      335.31                      334.97
# 491  12-13-2021                      340.68                      339.40
# 498  12-22-2021                      328.30                      333.20
# 499  12-23-2021                      332.75                      334.69
#
#      Microsoft Highest Price($)  Microsoft Lowest Price($)  \
# ...

# %%
train_microsoft_x = np.asarray(train_microsoft[['Microsoft Opening Price($)','Microsoft Closing Price($)','Microsoft Highest Price($)','Microsoft Lowest Price($)']])
train_microsoft_y = np.asarray(train_microsoft['Microsoft Trade Volume'])

test_microsoft_x = np.asarray(test_microsoft[['Microsoft Opening Price($)','Microsoft Closing Price($)','Microsoft Highest Price($)','Microsoft Lowest Price($)']])
test_microsoft_y = np.asarray(test_microsoft['Microsoft Trade Volume'])

# %%
regression_microsoft = linear_model.LinearRegression()
regression_microsoft.fit(train_microsoft_x,train_microsoft_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Regression Intercept:', regression_microsoft.intercept_)
print('Regression Coefficients:', regression_microsoft.coef_)
# Out:
# Regression Intercept: 44854377.85479702
# Regression Coefficients: [ -172966.138518    -144965.5774701   4037692.36451804 -3855870.98413483]

# %%
print('R-Squared value of the Microsoft training set: {}'.format(regression_microsoft.score(train_microsoft_x, train_microsoft_y)))
print('R-Squared value of the Microsoft testing set: {}'.format(regression_microsoft.score(test_microsoft_x, test_microsoft_y)))
# Out:
# R-Squared value of the Microsoft training set: 0.6952588361965792
# R-Squared value of the Microsoft testing set: 0.6905645287456914

# %% [markdown]
# ## Step 6: Visualize Results
#
# Build up your key visual story elements!
#
# Add more cells (`Insert > Insert Cell Below`) if you want additional cells.

# %% [markdown]
# ### Visualising the predicted data model of Apple.Inc

# %%
Apple_final_bar = pd.DataFrame({'Actual Trade volume of Apple':test_apple_y, 'Predicted Trade volume of Apple':regression.predict(test_apple_x)}, index=test_apple['Date'])
Apple_final_bar.plot.bar(figsize=(30,10))

# %%
Apple_final_graph = pd.DataFrame({'Actual Trade volume of Apple':test_apple_y, 'Predicted Trade volume of Apple':regression.predict(test_apple_x)})
Apple_final_graph
# Out:
#      Actual Trade volume of Apple  Predicted Trade volume of Apple
# 0                       146535520                     1.461750e+08
# 1                       118578560                     1.634587e+08
# 2                       111510640                     1.370607e+08
# 3                       122086880                     1.491070e+08
# 4                       146537520                     1.487027e+08
# ..                            ...                              ...
# 121                      63804010                     8.173143e+07
# 122                     116998900                     1.101808e+08
# 123                     153237000                     1.386978e+08
# 124                      92135300                     6.641225e+07
# 125                      68356570                     8.604871e+06
#
# [126 rows x 2 columns]

# %%
Apple_final_graph.plot(figsize=(15,5))

# %% [markdown]
# ### Visualising the predicted data model of Microsoft.Inc

# %%
Microsoft_final_bar = pd.DataFrame({'Actual Trade volume of Microsoft':test_microsoft_y, 'Predicted Trade volume of Microsoft':regression.predict(test_microsoft_x)}, index=test_microsoft['Date'])
Microsoft_final_bar.plot.bar(figsize=(30,10))

# %%
Microsoft_final = pd.DataFrame({'Actual Trade volume of Microsoft':test_microsoft_y, 'Predicted Trade volume of Microsoft':regression.predict(test_microsoft_x)})
Microsoft_final
# Out:
#      Actual Trade volume of Microsoft  Predicted Trade volume of Microsoft
# 0                            21121680                         4.931707e+07
# 1                            20826700                         6.059575e+07
# 2                            21881740                         5.337308e+07
# 3                            21637010                         3.930928e+07
# 4                            24918120                         5.658005e+07
# ..                                ...                                  ...
# 121                          23831050                        -1.697154e+08
# 122                          24760990                        -1.663416e+08
# 123                          28899430                        -1.317688e+08
# 124                          24831490                        -5.807193e+07
# 125                          19617850                        -1.542279e+08
#
# [126 rows x 2 columns]

# %%
Microsoft_final.plot(figsize=(15,5))

# %% [markdown]
# # Step 7: Communicate the Story to your intended audience using visualizations and narrative
# In a few paragraphs, describe the story the data tells.
#
# Additionally, post your most compelling visual and provide a brief description of what it conveys on to our mutual aid channel (the slack course channel).
#
# Feel free to post more examples for people to look at and provide feedback. Your classmates will be vital providers of feedback in this process. Utilize them.

# %% [markdown]
# #### Stock Market is highly volatile, and a number of reasons might trigger a significant rise or fall in the stock price. It takes a lot of research for a buyer/seller to find a good/bad stock as they would have to go through numerous sources to gain information about a particular company’s past performance as well as its future goals.
#
# #### This prediction model focuses on predicting the trade volume of a stock by considering the opening price, highest price, lowest price, and closing price. The trade volume of a stock represents the number of shares that were traded on that day, so the trading volume would be high when the stock is being bought or sold rapidly.
#
# #### The price of the stock along with this trading volume decides if the stock is in bullish or bearish trend. The stock is said to be in a bullish trend if the number of buyers is higher when compared to the number of sellers, and the stock is said to be in a bearish trend if the number of sellers is higher when compared to the number of buyers.
#
# #### Based on this trading volume, a buyer/seller might look into the stock and try to figure out why it has caused an interest/disinterest among the buyer/sellers. So, I am considering the stock values of 2 of the biggest IT companies in world namely Apple.Inc and Microsoft.Inc and predicting their trade volume based on their Stock opening price, closing price, highest price, and lowest price of that particular day.

# %% [markdown]
# # Final Step: Connect your workflow/process to the DSA-Project Life Cycle
# - List and briefly discuss how important details from each stage of the [DSA-PLC](../../module1/resources/DSA-ProjectLifecycle-slidedeck.pdf) played a role in your story development.
# - Use markdown to provide this overview below:
# <hr/>
#
# <h1 align="center"><u>DSA-Project Life Cycle Discussion</u></h1>

# %% [markdown]
# #### Listed below are the learnings I gained from each stage of the dsa project life cycle.
#
# #### 1. Project Definition, Requirements and Expectations :
# This phase helped me charaterise my audience, conduct initial backgroud research and describe preliminary research methods.
#
# #### 2. Data Aquisition Governance, Curation & Source Code Management :
# This phase helped me design, define, and establish dat aquisition techniques and to protect and maintain data.
#
# #### 3. Data Shaping and Carpentry :
# This phase helped me identify and remove irrelevant rows and columns, detect and manage missing and irrelevant data.
#
# #### 4. Exoloratory Data Analysis and Visualisation :
# This phase helped me asses the quality of data, identify and asses data relations using filtering and scaling.
#
# #### 5. Statistical/Machine Learning Model Planning Building Testing :
# This phase helped me specify outcome variables and predictor variables and determing model validation methods.
#
# #### 6. Statistical/Machine Learning Model Validation , Visualisation, Interpretation :
# This phase helped me to evaluate model performance, results, and outcomes to indetify new limitations or unexpected outcomes.
#
# #### 7. Data Story/Product Development and Reporting :
# This phase helped me express defined expectation and outcomes and outilne detailed narratives to audience and provide the outcomes.
#
# #### 8. Statistical/Machine Learning Model Development and Monitoring :
# This phase helped me deliver the final product and run the prediction model and evaluate the performance and made required updations.

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
